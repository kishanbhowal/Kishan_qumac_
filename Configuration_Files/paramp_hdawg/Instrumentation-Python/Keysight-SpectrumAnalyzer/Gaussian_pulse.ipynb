# %%
from scipy.signal import gaussian
import matplotlib.pyplot as plt 
import numpy as np

pi_len_ns = 100
t_list = np.linspace(16, pi_len_ns, int(pi_len_ns/0.1))

wf = [float(arg) for arg in 0.4 * gaussian(pi_len_ns, pi_len_ns//6)]

# %%
plt.plot(gaussian(pi_len_ns, pi_len_ns//6))

# %%
plt.plot(wf)
