# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
power_min, power_max, power_step = -30, 10, 5
power_list = np.arange(power_min, power_max + power_step/2 , power_step)

data_2d = []
for p in power_list:
    filepath = rf'D:\Experiments\2024-02-13 RingV1 wo qubits and 7 paramps\Low Temperature Response\Ring5_Input6Output30\PowerSweep\Real_{p}_dBm.txt'
    print(filepath)
    data= np.transpose(np.loadtxt(filepath))
    ydata=data[1]
    data_2d.append(ydata)
freq = data[0]
# Out:
# D:\Experiments\2024-02-13 RingV1 wo qubits and 7 paramps\Low Temperature Response\Ring5_Input6Output30\PowerSweep\Real_-30.0_dBm.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 8
#       6 filepath = rf'D:\Experiments\2024-02-13 RingV1 wo qubits and 7 paramps\Low Temperature Response\Ring5_Input6Output30\PowerSweep\Real_{p}_dBm.txt'
#       7 print(filepath)
# ----> 8 data= np.transpose(np.loadtxt(filepath))
#       9 ydata=data[1]
#      10 data_2d.append(ydata)
#
# File ~\miniconda3\lib\site-packages\numpy\lib\npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
for i,p in enumerate(power_list):
    plt.plot(freq, data_2d[i])
