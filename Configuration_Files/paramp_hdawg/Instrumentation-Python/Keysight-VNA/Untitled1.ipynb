# %%
import pyvisa as visa
import numpy as np
import matplotlib.pyplot as plt

# %%
 rm = visa.ResourceManager()

# %%
#myPna = rm.open_resource("PXI10::0-0.0::INSTR")
vna = rm.open_resource("TCPIP0::SDEVLOOP::hislip_PXI10_CHASSIS1_SLOT1_INDEX0::INSTR")

# %%
vna
# Out:
# <'TCPIPInstrument'('TCPIP0::SDEVLOOP::hislip_PXI10_CHASSIS1_SLOT1_INDEX0::INSTR')>

# %%
rm.list_resources()
# Out:
# ('GPIB0::24::INSTR',
#  'GPIB1::18::INSTR',
#  'PXI10::0-0.0::INSTR',
#  'TCPIP0::192.168.0.122::inst0::INSTR')

# %%
myPna.close()

# %%
rm.list_resources()
# Out:
# ('GPIB0::24::INSTR',
#  'GPIB1::18::INSTR',
#  'PXI10::0-0.0::INSTR',
#  'TCPIP0::192.168.0.122::inst0::INSTR')
