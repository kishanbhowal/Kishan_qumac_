# %%
import pyvisa as visa
import numpy as np
import matplotlib.pyplot as plt

# %%
 rm = visa.ResourceManager()

# %%
myPna = rm.open_resource("PXI10::0-0.0::INSTR")

# %%
myPna.timeout =  10000
myPna.write ("SYST:PRES; *OPC?")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 myPna.timeout =  10000
# ----> 2 myPna.write ("SYST:PRES; *OPC?")
#
# AttributeError: 'PXIInstrument' object has no attribute 'write'

# %%
myPna
# Out:
# <'PXIInstrument'('PXI10::0-0.0::INSTR')>

# %%
myPna.close()

# %%
rm.list_resources()
