# %%
import os
os.getcwd()
# Out:
# 'd:\\QUA\\Master_Scripts\\fourqubitv5 (Under Construction)'

# %%
from Configuration_Files.configuration_Learning import config

print("Config imported successfully")
# Out:
# 2026-02-20 12:37:50,966 - qm - INFO     - Starting session: 0f03ddd5-49e8-416b-ba0e-a0c0cc16917e
# Config imported successfully

# %%
from qm import QuantumMachinesManager

qmm = QuantumMachinesManager(host="192.168.0.118")
qm = qmm.open_qm(config)

print("QM Connected Successfully")
# Out:
# 2026-02-20 12:40:14,125 - qm - ERROR    - Failed to detect to QuantumMachines server, failed to connect to a cluster. Tried connecting to 192.168.0.118:80.
# Errors:
# 192.168.0.118:80:
# Traceback (most recent call last):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\anyio\_core\_tasks.py", line 115, in fail_after
#     yield cancel_scope
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\backends\asyncio.py", line 34, in read
#     return await self._stream.receive(max_bytes=max_bytes)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\anyio\_backends\_asyncio.py", line 1103, in receive
#     await self._protocol.read_event.wait()
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\asyncio\locks.py", line 214, in wait
#     await fut
# asyncio.exceptions.CancelledError: Cancelled by cancel scope 2b5030c5b70
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_exceptions.py", line 10, in map_exceptions
#     yield
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\backends\asyncio.py", line 32, in read
#     with anyio.fail_after(timeout):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\anyio\_core\_tasks.py", line 118, in fail_after
#     raise TimeoutError
# TimeoutError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_transports\default.py", line 60, in map_httpcore_exceptions
#     yield
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_transports\default.py", line 353, in handle_async_request
#     resp = await self._pool.handle_async_request(req)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\connection_pool.py", line 253, in handle_async_request
#     raise exc
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\connection_pool.py", line 237, in handle_async_request
#     response = await connection.handle_async_request(request)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\connection.py", line 90, in handle_async_request
#     return await self._connection.handle_async_request(request)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\http2.py", line 144, in handle_async_request
#     raise exc
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\http2.py", line 112, in handle_async_request
#     status, headers = await self._receive_response(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\http2.py", line 229, in _receive_response
#     event = await self._receive_stream_event(request, stream_id)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\http2.py", line 260, in _receive_stream_event
#     await self._receive_events(request, stream_id)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\http2.py", line 281, in _receive_events
#     events = await self._read_incoming_data(request)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\http2.py", line 341, in _read_incoming_data
#     raise exc
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\http2.py", line 327, in _read_incoming_data
#     data = await self._network_stream.read(self.READ_NUM_BYTES, timeout)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\backends\asyncio.py", line 31, in read
#     with map_exceptions(exc_map):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc)
# httpcore.ReadTimeout
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\api\server_detector.py", line 55, in detect_server
#     connection_details, octaves = _redirect(connection_details)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\api\server_detector.py", line 92, in _redirect
#     response_details = run_async(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\utils\async_utils.py", line 38, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\concurrent\futures\_base.py", line 458, in result
#     return self.__get_result()
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\concurrent\futures\_base.py", line 403, in __get_result
#     raise self._exception
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\communication\http_redirection.py", line 42, in send_redirection_check
#     response = await client.post(f"http://{host}:{port}", headers=extended_headers, content=bytes(Empty()))
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1848, in post
#     return await self.request(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1533, in request
#     return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1620, in send
#     response = await self._send_handling_auth(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1648, in _send_handling_auth
#     response = await self._send_handling_redirects(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1685, in _send_handling_redirects
#     response = await self._send_single_request(request)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1722, in _send_single_request
#     response = await transport.handle_async_request(request)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_transports\default.py", line 352, in handle_async_request
#     with map_httpcore_exceptions():
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_transports\default.py", line 77, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ReadTimeout
# .
# ---------------------------------------------------------------------------
# QmServerDetectionError                    Traceback (most recent call last)
# Cell In[4], line 3
#       1 from qm import QuantumMachinesManager
# ----> 3 qmm = QuantumMachinesManager(host="192.168.0.118")
#       4 qm = qmm.open_qm(config)
#       6 print("QM Connected Successfully")
#
# File c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\quantum_machines_manager.py:128, in QuantumMachinesManager.__init__(self, host, port, cluster_name, timeout, log_level, connection_headers, add_debug_data, credentials, store, file_store_root, octave, octave_calibration_db_path)
#     126 self._cluster_name = cluster_name
#     127 self._store = store if store else SimpleFileStore(file_store_root)
# --> 128 self._server_details = self._initialize_connection(
#     129     host=host,
#     130     port=port,
#     131     timeout=timeout,
#     132     add_debug_data=add_debug_data,
#     133     connection_headers=connection_headers,
#     134     credentials=credentials,
#     135 )
#     136 if self._server_details.octaves:
#     137     if octave is None:
#
# File c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\quantum_machines_manager.py:188, in QuantumMachinesManager._initialize_connection(self, host, port, timeout, add_debug_data, credentials, connection_headers)
#     179 def _initialize_connection(
#     180     self,
#     181     host: str,
#    (...)
#     186     connection_headers: Optional[Dict[str, str]],
#     187 ) -> ServerDetails:
# --> 188     server_details = detect_server(
#     189         cluster_name=self._cluster_name,
#     190         user_token=self._user_config.user_token,
#     191         ssl_context=credentials,
#     192         host=host,
#     193         port_from_user_config=self._user_config.manager_port,
#     194         user_provided_port=port,
#     195         add_debug_data=add_debug_data,
#     196         timeout=timeout,
#     197         extra_headers=connection_headers,
#     198     )
#     199     create_capabilities_container(server_details.qua_implementation)
#     200     return server_details
#
# File c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\api\server_detector.py:88, in detect_server(cluster_name, user_token, ssl_context, host, port_from_user_config, user_provided_port, add_debug_data, timeout, max_message_size, extra_headers)
#      86 errors_msgs = "\n".join([f"{dst}: {error}" for dst, error in errors])
#      87 logger.error(f"{message}\nErrors:\n{errors_msgs}.")
# ---> 88 raise QmServerDetectionError(message)
#
# QmServerDetectionError: Failed to detect to QuantumMachines server, failed to connect to a cluster. Tried connecting to 192.168.0.118:80.

# %%
from qm import QuantumMachinesManager

qmm = QuantumMachinesManager(
    host="192.168.0.118",
    port=9510
)

qm = qmm.open_qm(config)

print("QM Connected Successfully")
# Out:
# 2026-02-20 12:43:33,032 - qm - ERROR    - Failed to detect to QuantumMachines server, failed to connect to a cluster. Tried connecting to 192.168.0.118:9510.
# Errors:
# 192.168.0.118:9510: All connection attempts failed
# Traceback (most recent call last):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\anyio\_core\_sockets.py", line 168, in try_connect
#     stream = await asynclib.connect_tcp(remote_host, remote_port, local_address)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\anyio\_backends\_asyncio.py", line 2202, in connect_tcp
#     await get_running_loop().create_connection(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\asyncio\base_events.py", line 1076, in create_connection
#     raise exceptions[0]
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\asyncio\base_events.py", line 1060, in create_connection
#     sock = await self._connect_sock(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\asyncio\base_events.py", line 969, in _connect_sock
#     await self.sock_connect(sock, address)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\asyncio\selector_events.py", line 501, in sock_connect
#     return await fut
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\asyncio\selector_events.py", line 541, in _sock_connect_cb
#     raise OSError(err, f'Connect call failed {address}')
# TimeoutError: [Errno 10060] Connect call failed ('192.168.0.118', 9510)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_exceptions.py", line 10, in map_exceptions
#     yield
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\backends\asyncio.py", line 111, in connect_tcp
#     stream: anyio.abc.ByteStream = await anyio.connect_tcp(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\anyio\_core\_sockets.py", line 230, in connect_tcp
#     raise OSError("All connection attempts failed") from cause
# OSError: All connection attempts failed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_transports\default.py", line 60, in map_httpcore_exceptions
#     yield
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_transports\default.py", line 353, in handle_async_request
#     resp = await self._pool.handle_async_request(req)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\connection_pool.py", line 253, in handle_async_request
#     raise exc
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\connection_pool.py", line 237, in handle_async_request
#     response = await connection.handle_async_request(request)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\connection.py", line 86, in handle_async_request
#     raise exc
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\connection.py", line 63, in handle_async_request
#     stream = await self._connect(request)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_async\connection.py", line 111, in _connect
#     stream = await self._network_backend.connect_tcp(**kwargs)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\backends\auto.py", line 29, in connect_tcp
#     return await self._backend.connect_tcp(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\backends\asyncio.py", line 109, in connect_tcp
#     with map_exceptions(exc_map):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc)
# httpcore.ConnectError: All connection attempts failed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\api\server_detector.py", line 55, in detect_server
#     connection_details, octaves = _redirect(connection_details)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\api\server_detector.py", line 92, in _redirect
#     response_details = run_async(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\utils\async_utils.py", line 38, in run_async
#     return create_future(coroutine).result()  # type: ignore[no-any-return]
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\concurrent\futures\_base.py", line 458, in result
#     return self.__get_result()
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\concurrent\futures\_base.py", line 403, in __get_result
#     raise self._exception
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\communication\http_redirection.py", line 42, in send_redirection_check
#     response = await client.post(f"http://{host}:{port}", headers=extended_headers, content=bytes(Empty()))
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1848, in post
#     return await self.request(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1533, in request
#     return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1620, in send
#     response = await self._send_handling_auth(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1648, in _send_handling_auth
#     response = await self._send_handling_redirects(
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1685, in _send_handling_redirects
#     response = await self._send_single_request(request)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_client.py", line 1722, in _send_single_request
#     response = await transport.handle_async_request(request)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_transports\default.py", line 352, in handle_async_request
#     with map_httpcore_exceptions():
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\httpx\_transports\default.py", line 77, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectError: All connection attempts failed
# .
# ---------------------------------------------------------------------------
# QmServerDetectionError                    Traceback (most recent call last)
# Cell In[5], line 3
#       1 from qm import QuantumMachinesManager
# ----> 3 qmm = QuantumMachinesManager(
#       4     host="192.168.0.118",
#       5     port=9510
#       6 )
#       8 qm = qmm.open_qm(config)
#      10 print("QM Connected Successfully")
#
# File c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\quantum_machines_manager.py:128, in QuantumMachinesManager.__init__(self, host, port, cluster_name, timeout, log_level, connection_headers, add_debug_data, credentials, store, file_store_root, octave, octave_calibration_db_path)
#     126 self._cluster_name = cluster_name
#     127 self._store = store if store else SimpleFileStore(file_store_root)
# --> 128 self._server_details = self._initialize_connection(
#     129     host=host,
#     130     port=port,
#     131     timeout=timeout,
#     132     add_debug_data=add_debug_data,
#     133     connection_headers=connection_headers,
#     134     credentials=credentials,
#     135 )
#     136 if self._server_details.octaves:
#     137     if octave is None:
#
# File c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\quantum_machines_manager.py:188, in QuantumMachinesManager._initialize_connection(self, host, port, timeout, add_debug_data, credentials, connection_headers)
#     179 def _initialize_connection(
#     180     self,
#     181     host: str,
#    (...)
#     186     connection_headers: Optional[Dict[str, str]],
#     187 ) -> ServerDetails:
# --> 188     server_details = detect_server(
#     189         cluster_name=self._cluster_name,
#     190         user_token=self._user_config.user_token,
#     191         ssl_context=credentials,
#     192         host=host,
#     193         port_from_user_config=self._user_config.manager_port,
#     194         user_provided_port=port,
#     195         add_debug_data=add_debug_data,
#     196         timeout=timeout,
#     197         extra_headers=connection_headers,
#     198     )
#     199     create_capabilities_container(server_details.qua_implementation)
#     200     return server_details
#
# File c:\Users\qumac\miniconda3\envs\hari_env\lib\site-packages\qm\api\server_detector.py:88, in detect_server(cluster_name, user_token, ssl_context, host, port_from_user_config, user_provided_port, add_debug_data, timeout, max_message_size, extra_headers)
#      86 errors_msgs = "\n".join([f"{dst}: {error}" for dst, error in errors])
#      87 logger.error(f"{message}\nErrors:\n{errors_msgs}.")
# ---> 88 raise QmServerDetectionError(message)
#
# QmServerDetectionError: Failed to detect to QuantumMachines server, failed to connect to a cluster. Tried connecting to 192.168.0.118:9510.
